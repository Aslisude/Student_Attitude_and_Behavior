# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("Student Attitude and Behavior.csv")
df
# Out:
#     Certification Course  Gender Department  Height(CM)  Weight(KG)  \
# 0                     No    Male        BCA       100.0        58.0
# 1                     No  Female        BCA        90.0        40.0
# 2                    Yes    Male        BCA       159.0        78.0
# 3                    Yes  Female        BCA       147.0        20.0
# 4                     No    Male        BCA       170.0        54.0
# ..                   ...     ...        ...         ...         ...
# 230                  Yes    Male  B.com ISM       170.0        76.0
# 231                  Yes    Male  B.com ISM       172.0        52.0
# 232                  Yes  Female        BCA       139.0        33.0
# 233                  Yes  Female   Commerce       153.0        58.0
# 234                   No  Female  B.com ISM       155.0        39.0
#
#      10th Mark  12th Mark  college mark        hobbies daily studing time  \
# 0         79.0       64.0          80.0    Video Games      0 - 30 minute
# ...

# %%
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       71.0
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       64.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 19 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Certification Course                                    235 non-null    object
#  1   Gender                                                  235 non-null    object
#  2   Department                                              235 non-null    object
#  3   Height(CM)                                              235 non-null    float64
#  4   Weight(KG)                                              235 non-null    float64
#  5   10th Mark                                               235 non-null    float64
#  6   12th Mark                                               235 non-null    float64
#  7   college mark                                            235 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Height(CM)  Weight(KG)   10th Mark   12th Mark  college mark  \
# count  235.000000  235.000000  235.000000  235.000000    235.000000
# mean   157.402128   60.803830   76.848511   68.775872     70.660553
# std     21.510805   14.895844   13.047560   11.018192     15.727446
# min      4.500000   20.000000    7.400000   45.000000      1.000000
# 25%    152.000000   50.000000   70.000000   60.000000     60.000000
# 50%    160.000000   60.000000   80.000000   69.000000     70.000000
# 75%    170.000000   70.000000   86.250000   76.000000     80.000000
# max    192.000000  106.000000   98.000000   94.000000    100.000000
#
#        salary expectation
# count        2.350000e+02
# mean         3.248168e+04
# std          1.113146e+05
# min          0.000000e+00
# 25%          1.500000e+04
# 50%          2.000000e+04
# 75%          2.500000e+04
# max          1.500000e+06

# %%
df.isnull().any()
# Out:
# Certification Course                                      False
# Gender                                                    False
# Department                                                False
# Height(CM)                                                False
# Weight(KG)                                                False
# 10th Mark                                                 False
# 12th Mark                                                 False
# college mark                                              False
# hobbies                                                   False
# daily studing time                                        False
# prefer to study in                                        False
# salary expectation                                        False
# Do you like your degree?                                  False
# willingness to pursue a career based on their degree      False
# social medai & video                                      False
# ...

# %%
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       71.0
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       64.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
df["daily studing time"].unique()
# Out:
# array(['0 - 30 minute', '30 - 60 minute', '1 - 2 Hour', '2 - 3 hour',
#        '3 - 4 hour', 'More Than 4 hour'], dtype=object)

# %%
df["hobbies"].unique()
# Out:
# array(['Video Games', 'Cinema', 'Reading books', 'Sports'], dtype=object)

# %%
df["daily studing time"].value_counts()
# Out:
# daily studing time
# 30 - 60 minute      81
# 1 - 2 Hour          61
# 0 - 30 minute       46
# 2 - 3 hour          24
# 3 - 4 hour          15
# More Than 4 hour     8
# Name: count, dtype: int64

# %%
df.groupby("daily studing time")[["college mark"]].mean().reset_index()
# Out:
#   daily studing time  college mark
# 0      0 - 30 minute     68.690435
# 1         1 - 2 Hour     70.317541
# 2         2 - 3 hour     75.929167
# 3         3 - 4 hour     75.520000
# 4     30 - 60 minute     69.864198
# 5   More Than 4 hour     67.750000

# %%
df["hobbies"].unique()
# Out:
# array(['Video Games', 'Cinema', 'Reading books', 'Sports'], dtype=object)

# %%
df["social medai & video"].unique()
# Out:
# array(['1.30 - 2 hour', '1 - 1.30 hour', 'More than 2 hour',
#        '30 - 60 Minute', '1 - 30 Minute', '0 Minute'], dtype=object)

# %%
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       71.0
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       64.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
df.groupby("Gender")[["Height(CM)"]].mean().reset_index()
# Out:
#    Gender  Height(CM)
# 0  Female  150.348101
# 1    Male  160.974359

# %%
df.groupby("Gender")[["Weight(KG)"]].mean().reset_index()
# Out:
#    Gender  Weight(KG)
# 0  Female   50.468354
# 1    Male   66.037821

# %%
Student_Attitude_and_Behavior = df.groupby("hobbies")[["salary expectation"]].mean().reset_index()

plt.figure(figsize=(18,5))
plt.bar(x = "hobbies", height = "salary expectation", data =Student_Attitude_and_Behavior )
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(18,5))
sns.barplot(x = "hobbies", y = "salary expectation", data =Student_Attitude_and_Behavior)
plt.xticks(rotation=90);

# %%
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       71.0
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       64.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
Student_Attitude_and_Behavior = df.groupby("Department")[["10th Mark","12th Mark"]].mean().reset_index()
Student_Attitude_and_Behavior
# Out:
#                       Department  10th Mark  12th Mark
# 0  B.com Accounting and Finance   74.226667  78.033333
# 1                      B.com ISM  63.392857  61.892857
# 2                            BCA  77.961364  66.205000
# 3                       Commerce  81.335000  75.329500

# %%
Student_Attitude_and_Behavior = df.groupby(["daily studing time","Do you like your degree?"])[["salary expectation"]].mean().reset_index()
Student_Attitude_and_Behavior
# Out:
#    daily studing time Do you like your degree?  salary expectation
# 0       0 - 30 minute                       No        19400.000000
# 1       0 - 30 minute                      Yes        32683.341463
# 2          1 - 2 Hour                       No       312600.000000
# 3          1 - 2 Hour                      Yes        20991.732143
# 4          2 - 3 hour                      Yes        25000.000000
# 5          3 - 4 hour                       No        16673.333333
# 6          3 - 4 hour                      Yes        19251.750000
# 7      30 - 60 minute                       No        17600.000000
# 8      30 - 60 minute                      Yes        20975.000000
# 9    More Than 4 hour                       No        21250.000000
# 10   More Than 4 hour                      Yes       142000.000000

# %%
plt.figure(figsize=(8,5))
sns.barplot( x = "daily studing time", y = "salary expectation",data =Student_Attitude_and_Behavior )
plt.xticks(rotation=90);

# %%
Student_Attitude_and_Behavior = df.groupby("Financial Status")[["10th Mark","12th Mark"]].mean().reset_index()
Student_Attitude_and_Behavior
# Out:
#   Financial Status  10th Mark  12th Mark
# 0            Awful  78.135714  66.142857
# 1              Bad  76.555682  69.145455
# 2         Fabulous  72.250000  64.750000
# 3             good  77.051163  68.934341

# %%
df.groupby("Do you like your degree?")[["salary expectation"]].agg(["mean","max","min"]).reset_index()
# Out:
#   Do you like your degree? salary expectation
#                                          mean      max min
# 0                       No       92026.000000  1500000  10
# 1                      Yes       26942.674419   700000   0

# %%
df.groupby("Gender")[["salary expectation"]].agg(["mean","max","min"]).reset_index()
# Out:
#    Gender salary expectation
#                         mean      max min
# 0  Female       38165.000000  1500000  10
# 1    Male       29603.589744   700000   0

# %%
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       71.0
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       64.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
df["prefer to study in"].unique()
# Out:
# array(['Morning', 'Anytime', 'Night'], dtype=object)

# %%
df["prefer to study in"].value_counts()
# Out:
# prefer to study in
# Anytime    111
# Morning     77
# Night       47
# Name: count, dtype: int64

# %%
df["hobbies"].unique()
# Out:
# array(['Video Games', 'Cinema', 'Reading books', 'Sports'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.barplot(x = "hobbies",y = "salary expectation",hue="Gender",data=Student_Attitude_and_Behavior)
plt.title("Student Attitude and Behavior")
plt.xlabel("hobbies")
plt.ylabel("Salary")
plt.legend(loc="upper right")
plt.xticks(rotation=90);

# %%
df["social medai & video"].unique()
# Out:
# array(['1.30 - 2 hour', '1 - 1.30 hour', 'More than 2 hour',
#        '30 - 60 Minute', '1 - 30 Minute', '0 Minute'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.barplot(x = "social medai & video",y = "Weight(KG)",hue="part-time job",data=Student_Attitude_and_Behavior)
plt.title("Student Attitude and Behavior")
plt.xlabel("social medai & video")
plt.ylabel("Weight(KG)")
plt.legend(loc="upper right")
plt.xticks(rotation=90);

# %%
df["hobbies"].unique()
# Out:
# array(['Video Games', 'Cinema', 'Reading books', 'Sports'], dtype=object)

# %%
df["Financial Status"].unique()
# Out:
# array(['Bad', 'good', 'Awful', 'Fabulous'], dtype=object)

# %%
df["Stress Level "].unique()
# Out:
# array(['Bad', 'Awful', 'Good', 'fabulous'], dtype=object)

# %%
df["willingness to pursue a career based on their degree  "].unique()
# Out:
# array(['50%', '75%', '25%', '100%', '0%'], dtype=object)

# %%
Student_Attitude_and_Behavior = df.groupby(["willingness to pursue a career based on their degree  ","Stress Level "])[["salary expectation"]].mean().reset_index()
Student_Attitude_and_Behavior
# Out:
#    willingness to pursue a career based on their degree   Stress Level   \
# 0                                                  0%              Good
# 1                                                100%             Awful
# 2                                                100%               Bad
# 3                                                100%              Good
# 4                                                100%          fabulous
# 5                                                 25%             Awful
# 6                                                 25%               Bad
# 7                                                 25%              Good
# 8                                                 25%          fabulous
# 9                                                 50%             Awful
# 10                                                50%               Bad
# 11                                                50%              Good
# ...
